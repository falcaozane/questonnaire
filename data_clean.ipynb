# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("profiles.csv",sep=",")

# %%
df.head(10)
# Out:
#    Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q18  Q19  Q20  Q21  Q22  Q23  \
# 0   5   4   1   5   5   5   1   3   5    5  ...    2    2    2    1    3    1
# 1   4   2   4   3   3   5   5   2   3    2  ...    3    2    1    5    3    1
# 2   2   2   3   2   3   1   3   4   1    5  ...    5    5    1    2    3    4
# 3   2   1   4   1   2   2   5   5   1    5  ...    5    1    1    2    1    2
# 4   5   4   5   3   4   1   1   4   5    1  ...    1    2    3    4    3    4
# 5   2   3   2   4   5   4   5   5   2    4  ...    5    4    2    3    4    4
# 6   2   2   5   1   4   3   5   1   1    5  ...    4    4    1    2    4    2
# 7   3   2   1   1   3   5   2   5   1    3  ...    1    4    4    3    2    4
# 8   4   4   2   5   2   1   3   5   5    5  ...    5    1    4    2    5    5
# 9   4   1   1   2   3   1   2   1   3    3  ...    2    2    5    4    1    4
#
#    Q24  Q25  Q26  leadership_style
# 0    2    5    4       Pacesetting
# 1    2    3    2        Delegative
# ...

# %%
df.shape
# Out:
# (20009, 27)

# %%
df.Q1.duplicated().sum()
# Out:
# np.int64(20004)

# %%
df.Q2.duplicated().sum()
# Out:
# np.int64(20004)

# %%
df.loc[df.Q1.duplicated(),:]
# Out:
#        Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q18  Q19  Q20  Q21  Q22  \
# 3       2   1   4   1   2   2   5   5   1    5  ...    5    1    1    2    1
# 4       5   4   5   3   4   1   1   4   5    1  ...    1    2    3    4    3
# 5       2   3   2   4   5   4   5   5   2    4  ...    5    4    2    3    4
# 6       2   2   5   1   4   3   5   1   1    5  ...    4    4    1    2    4
# 8       4   4   2   5   2   1   3   5   5    5  ...    5    1    4    2    5
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...
# 20004   3   3   1   2   3   3   1   5   5    3  ...    2    3    5    5    4
# 20005   2   2   4   5   4   2   5   2   2    2  ...    1    2    2    4    4
# 20006   4   1   3   2   5   4   2   2   5    5  ...    4    1    1    3    2
# 20007   5   4   4   1   3   2   5   5   5    3  ...    3    4    3    2    2
# 20008   5   3   5   2   1   5   1   5   1    3  ...    5    4    3    2    1
#
#        Q23  Q24  Q25  Q26  leadership_style
# ...

# %%
df.loc[df.Q2.duplicated(),:]
# Out:
#        Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8  Q9  Q10  ...  Q18  Q19  Q20  Q21  Q22  \
# 2       2   2   3   2   3   1   3   4   1    5  ...    5    5    1    2    3
# 4       5   4   5   3   4   1   1   4   5    1  ...    1    2    3    4    3
# 6       2   2   5   1   4   3   5   1   1    5  ...    4    4    1    2    4
# 7       3   2   1   1   3   5   2   5   1    3  ...    1    4    4    3    2
# 8       4   4   2   5   2   1   3   5   5    5  ...    5    1    4    2    5
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...
# 20004   3   3   1   2   3   3   1   5   5    3  ...    2    3    5    5    4
# 20005   2   2   4   5   4   2   5   2   2    2  ...    1    2    2    4    4
# 20006   4   1   3   2   5   4   2   2   5    5  ...    4    1    1    3    2
# 20007   5   4   4   1   3   2   5   5   5    3  ...    3    4    3    2    2
# 20008   5   3   5   2   1   5   1   5   1    3  ...    5    4    3    2    1
#
#        Q23  Q24  Q25  Q26  leadership_style
# ...

# %%
clean_df = df.drop_duplicates(keep=False)
clean_df.to_csv('cleaned_data.csv', index=False)
